# %%
import pandas as pd
from tqdm import tqdm

# %%
df = pd.read_csv(r"C:\Users\vikas\Downloads\songs.csv")

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.describe()
# Out:
#                        name           singer                singer_id  \
# count                 41355            41355                    41355
# unique                31534             6196                     6580
# top     O Mere Dil Ke Chain  Lata Mangeshkar  /artist/lata-mangeshkar
# freq                     26             1410                     1410
#
#        duration                 link language
# count     41355                41355    41355
# unique     1309                36361       16
# top       03:02  /kya-khoob-lagti-ho   Telugu
# freq        447                    2     4996

# %% [markdown]
# #### checking the null values

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %% [markdown]
# ## Data Anlaysis

# %% [markdown]
# ___dealing with duration___

# %%
#  converting it into sec

df['duration']
# Out:
# 0        05:00
# 1        06:26
# 2        03:41
# 3        04:26
# 4        05:39
#          ...
# 41350    03:23
# 41351    03:56
# 41352    07:36
# 41353    04:29
# 41354    03:22
# Name: duration, Length: 41355, dtype: object

# %%
for i in df['duration'][:50]:
    print('min',int(i.split(':')[0]))
    print('sec',int(i.split(':')[1]))
# Out:
# min 5
# sec 0
# min 6
# sec 26
# min 3
# sec 41
# min 4
# sec 26
# min 5
# sec 39
# min 7
# sec 59
# min 4
# sec 48
# min 5
# sec 21
# min 3
# sec 9
# min 4
# sec 24
# min 5
# sec 3
# min 4
# sec 0
# min 4
# sec 43
# min 5
# sec 39
# min 7
# sec 29
# min 3
# sec 48
# min 3
# sec 24
# min 3
# sec 39
# min 5
# sec 22
# min 5
# sec 59
# min 6
# sec 21
# min 4
# sec 31
# min 4
# sec 23
# min 2
# sec 36
# min 4
# sec 49
# min 4
# sec 40
# min 7
# sec 38
# min 6
# sec 43
# min 7
# sec 22
# min 5
# sec 57
# min 3
# sec 37
# min 5
# sec 1
# min 3
# sec 36
# min 3
# sec 48
# min 4
# sec 51
# min 3
# sec 16
# min 5
# sec 2
# min 5
# sec 43
# min 3
# sec 19
# min 4
# sec 24
# min 2
# sec 35
# min 4
# sec 48
# min 5
# sec 54
# min 3
# sec 16
# min 3
# sec 32
# min 3
# sec 6
# min 2
# sec 35
# min 4
# sec 1
# min 5
# sec 7
# min 3
# sec 17

# %%
duration_list = []
for i in df['duration']:
    m = int(i.split(':')[0])
    s = int(i.split(':')[1])
    sec = (m*60 + s)
    duration_list.append(sec)
df['duration'] = duration_list
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id  duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1       300
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1       386
# 2                       /artist/jagjeet-singh-1       221
# 3                          /artist/chitra-singh       266
# 4                       /artist/jagjeet-singh-1       339
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# ...

# %%
len(duration_list)
# Out:
# 41355

# %% [markdown]
# ### Data Analayas

# %%
# what is the avg durationm of the song to the data set

df['duration'].mean()
# Out:
# 295.3130697618184

# %%
int(df['duration'].mean())
# Out:
# 295

# %%
# how many languges of songs are thier in the data set

df['language'].nunique()
# Out:
# 16

# %%
# what are the languges in the data set
df['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %%
# how many punjabi songs are thier 

c = 0
for i in df['language']:
    if i =='Punjabi':
        c += 1
        
print('there are ',c, 'songs in the data set')
# Out:
# there are  3818 songs in the data set

# %%
df['language'] == 'Punjabi'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41350    False
# 41351    False
# 41352    False
# 41353    False
# 41354    False
# Name: language, Length: 41355, dtype: bool

# %%
punjabi = df['language'] == 'Punjabi'

# %%
df[punjabi]
# Out:
#                                              name  \
# 14236                          Pehle Lalkare Naal
# 14237                 Sharbat Wangu Ghut Bhar Lan
# 14238                              Jija Lak Minle
# 14239                            Laija Kithe Door
# 14240                        Das Meriya Dilwarave
# ...                                           ...
# 18049                                  I Love You
# 18050                         Aeh Dunya Lag Di Ae
# 18051  Nak Nathli Tey Akhan (From "Balocha Daku")
# 18052                       Main Kiyoon Na Tenoon
# 18053                            Jehra Karda Zulm
#
#                             singer  \
# 14236  Amar Singh Chamkila|Amarjot
# 14237  Amar Singh Chamkila|Amarjot
# 14238  Amar Singh Chamkila|Amarjot
# 14239  Amar Singh Chamkila|Amarjot
# 14240    Asha Bhosle|Mohammed Rafi
# ...                            ...
# 18049                 Nahid Akhtar
# 18050                   Noor Jehan
# ...

# %%
df[df['language']=='Punjabi']
# Out:
#                                              name  \
# 14236                          Pehle Lalkare Naal
# 14237                 Sharbat Wangu Ghut Bhar Lan
# 14238                              Jija Lak Minle
# 14239                            Laija Kithe Door
# 14240                        Das Meriya Dilwarave
# ...                                           ...
# 18049                                  I Love You
# 18050                         Aeh Dunya Lag Di Ae
# 18051  Nak Nathli Tey Akhan (From "Balocha Daku")
# 18052                       Main Kiyoon Na Tenoon
# 18053                            Jehra Karda Zulm
#
#                             singer  \
# 14236  Amar Singh Chamkila|Amarjot
# 14237  Amar Singh Chamkila|Amarjot
# 14238  Amar Singh Chamkila|Amarjot
# 14239  Amar Singh Chamkila|Amarjot
# 14240    Asha Bhosle|Mohammed Rafi
# ...                            ...
# 18049                 Nahid Akhtar
# 18050                   Noor Jehan
# ...

# %%
len(df[df['language']=='Punjabi'])
# Out:
# 3818

# %% [markdown]
# @@ number od songs in each languge

# %%
for i in df['language'].unique():
    print(i)
# Out:
# Urdu
# Gujarati
# Tamil
# Kannada
# Rajasthani
# Haryanvi
# Punjabi
# Hindi
# Old
# Malayalam
# Marathi
# Telugu
# Odia
# Bhojpuri
# Assamese
# Bengali

# %%
c = 0
for i in df['language']:
    if i =='Punjabi':
        c += 1
print(c)
# Out:
# 3818

# %%
c = 0
for i in df['language']:
    if i =='Hindi':
        c += 1
print(c)
# Out:
# 4993

# %%
for lang in df['language'].unique():   
    c = 0
    for i in df['language']:
        if i == lang:
            c += 1
    print(lang,c)
# Out:
# Urdu 3116
# Gujarati 2115
# Tamil 4677
# Kannada 3559
# Rajasthani 541
# Haryanvi 228
# Punjabi 3818
# Hindi 4993
# Old 4993
# Malayalam 479
# Marathi 4699
# Telugu 4996
# Odia 940
# Bhojpuri 519
# Assamese 724
# Bengali 958

# %%
# another way
for lang in df['language'].unique():
    
    print(lang,len(df[df['language']==lang]))
# Out:
# Urdu 3116
# Gujarati 2115
# Tamil 4677
# Kannada 3559
# Rajasthani 541
# Haryanvi 228
# Punjabi 3818
# Hindi 4993
# Old 4993
# Malayalam 479
# Marathi 4699
# Telugu 4996
# Odia 940
# Bhojpuri 519
# Assamese 724
# Bengali 958

# %%
# avg duration of songs in each languge 

df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id  duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1       300
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1       386
# 2                       /artist/jagjeet-singh-1       221
# 3                          /artist/chitra-singh       266
# 4                       /artist/jagjeet-singh-1       339
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# ...

# %%
for lang in df['language'].unique():
    print(lang,int(df[df['language']==lang]['duration'].mean()))
# Out:
# Urdu 407
# Gujarati 271
# Tamil 270
# Kannada 250
# Rajasthani 291
# Haryanvi 320
# Punjabi 324
# Hindi 307
# Old 307
# Malayalam 242
# Marathi 281
# Telugu 279
# Odia 257
# Bhojpuri 357
# Assamese 228
# Bengali 255

# %%
#  how many singers are ther in the data set

all_singer = []
for singers in df['singer']:
    all_singer += singers.split('|')
print('Total singer are :',len(set(all_singer)))
# Out:
# Total singer are : 3940

# %%
len(all_singer)
# Out:
# 60166

# %%
len(set(all_singer))
# Out:
# 3940

# %% [markdown]
# ### how many songs has been sung by each singer

# %%
uni_singer = list(set(all_singer))

# %%
uni_singer
# Out:
# ['Muhammad Arif Lohar',
#  'Swagtika Mohapatra',
#  'Chaman Lal Chaman',
#  'Yashvant Thakur',
#  'Subhash Das',
#  'Anita Samana',
#  'M Ramesh',
#  'Amir Singh Rana',
#  'Harcharan Singh Safri',
#  'Mohd. Siddiq',
#  'Unspecified',
#  'Krishna Kale',
#  'Bal Palsule',
#  'Ruma Guha Thakurta',
#  'Ghulam Kadar Hashmi Qawwal',
#  'Hema Desai',
#  'S.S. Dhillon',
#  'Eunuchs',
#  'Mukkamala Sunanda',
#  'Kiran Abbot',
#  'Janardan Rawal',
#  'Pradeep Kumar',
#  'Latha Hamsalekha',
#  'Asha Ramani',
#  'Shakuntala Joshi',
#  'Vyjayanthimala',
#  'Swaroop Naik',
#  'Subhasish',
#  'Rajkumar Rizvi',
#  'Alam Lohar',
#  'Minoo Purshottam',
#  'Gul Bahar Bano',
#  'Betty Prince',
#  'Abhishek Bachchan',
#  'Ranima Devi',
#  'Harbert Murril',
#  'K.V. Prasad',
#  'Resham Singh Resham',
#  'Damodar Shirvale',
#  'Nayab Bano',
#  'Prathima Athreya',
#  'Savita',
#  'Sanjay Oza',
#  'Chimanbhai Dantani',
#  'Anup Jalota',
#  'Rachhpal Singh Rasila',
#  'Lakhabhai Gadhvi',
# ...

# %%
for i in uni_singer[:10]:
    print(i)
# Out:
# Muhammad Arif Lohar
# Swagtika Mohapatra
# Chaman Lal Chaman
# Yashvant Thakur
# Subhash Das
# Anita Samana
# M Ramesh
# Amir Singh Rana
# Harcharan Singh Safri
# Mohd. Siddiq

# %%
c = 0
for i in df['singer']:
    if i == 'Jagjit Singh':
        c+= 1
print(c)
# Out:
# 172

# %%
df.groupby('singer').size()['Jagjit Singh']   # another way
# Out:
# 172

# %%
c = 0
for i in df['singer']:
    if 'Jagjit Singh' in i:
        c+= 1
print(c)
# Out:
# 255

# %%
data = []

uni_singer = list(set(all_singer))
for i in tqdm(uni_singer):
    c = 0
    for singers in df['singer']:
        if i in singers:
            c += 1
    data.append([i,c])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 3940/3940 [00:29<00:00, 131.72it/s]

# %%
songs = pd.DataFrame(data,columns=['singer','songs'])
songs.head()
# Out:
#                 singer  songs
# 0  Muhammad Arif Lohar      8
# 1   Swagtika Mohapatra     12
# 2    Chaman Lal Chaman      2
# 3      Yashvant Thakur      4
# 4          Subhash Das     15

# %%
songs
# Out:
#                    singer  songs
# 0     Muhammad Arif Lohar      8
# 1      Swagtika Mohapatra     12
# 2       Chaman Lal Chaman      2
# 3         Yashvant Thakur      4
# 4             Subhash Das     15
# ...                   ...    ...
# 3935    Master Sajjad Ali     12
# 3936             Vasantha     98
# 3937              Mahathi      1
# 3938             Nagamani      1
# 3939      Sadananda Gogoi      1
#
# [3940 rows x 2 columns]

# %%
songs.sort_values(by='songs',ascending=False)
# Out:
#                       singer  songs
# 1678  S. P. Balasubrahmanyam   3659
# 2636                   Kumar   3270
# 3566                 Susheel   3216
# 2969                Susheela   3215
# 3749             P. Susheela   3213
# ...                      ...    ...
# 2684                 Benerji      1
# 1092             Shanta Apte      1
# 1095            Nisha Bhagat      1
# 1097                 Ananthu      1
# 3939         Sadananda Gogoi      1
#
# [3940 rows x 2 columns]

# %% [markdown]
# ### who has sing most number of songs in each languge

# %%
for lang in df['language'].unique():
    df_ = df[df['language']==lang]
    
    all_singer = []
    for singers in df_['singer']:
        all_singer += singers.split('|')
    print(lang,len(set(all_singer)))
# Out:
# Urdu 385
# Gujarati 303
# Tamil 510
# Kannada 379
# Rajasthani 218
# Haryanvi 76
# Punjabi 636
# Hindi 515
# Old 515
# Malayalam 72
# Marathi 569
# Telugu 369
# Odia 243
# Bhojpuri 109
# Assamese 228
# Bengali 192

# %%
for lang in df['language'].unique():
    df_ = df[df['language']==lang]
    
    all_singer = []
    for singers in df_['singer']:
        all_singer += singers.split('|')
    print(lang,len(df_),len(set(all_singer)))
# Out:
# Urdu 3116 385
# Gujarati 2115 303
# Tamil 4677 510
# Kannada 3559 379
# Rajasthani 541 218
# Haryanvi 228 76
# Punjabi 3818 636
# Hindi 4993 515
# Old 4993 515
# Malayalam 479 72
# Marathi 4699 569
# Telugu 4996 369
# Odia 940 243
# Bhojpuri 519 109
# Assamese 724 228
# Bengali 958 192
